# %%
import pickle
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pickle.load(open('../../pickles/1.50104722918e+12.p', 'rb'))

# %%
len(data)
# Out:
# 100

# %%
images = [d[-1] for d in data]

# %%
len(images)
# Out:
# 100

# %%
plt.imshow(images[0], cmap='gray')
